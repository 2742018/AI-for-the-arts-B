# %% [markdown]
# # Hello, World!
#
# The following code was created to refresh my memory with coding in Github for the course AI for the Arts (B). It is meant to help me re-familiarise how to write and run code in GitHub Codespaces.

# %%
print("Hello, World!")
# Out:
# Hello, World!
