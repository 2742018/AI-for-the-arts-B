# %% [markdown]
# # Access Through Touch: Disability, Reading, and Accessibility Through the Raised-Type New Testament
#
# ## Introduction
#
# This project explores a tactile New Testament printed in high relief for blind readers, held in the University of Glasgow Special Collections as **Sp Coll RF 256 / RF 257**. The object is significant because it challenges a common assumption about reading: that reading is mainly visual. Unlike an ordinary printed book, this New Testament was designed so that its letters could be read through touch. Its raised letterforms, spacing, and material surface invite us to understand reading as an embodied activity shaped by design, technology, and access.
#
# The project presents the object through a small public-facing digital mini-exhibit titled **Access Through Touch**. The aim is not to reproduce the experience of touching the object, because a digital notebook cannot recreate pressure, texture, or fingertip movement. Instead, the project uses photographs, relief-enhanced visual aids, plain-language interpretation, and access-description writing to help a general audience think about the object as a historical accessibility technology.
#
# The central argument of the project is that **accessibility is part of cultural heritage**. Accessibility should not be understood only as a modern support feature added after a collection has already been interpreted. This object shows that access has a history. It reveals how religious knowledge, literacy, disability, and material design intersected in the nineteenth century. By focusing on the tactile qualities of the page, the project asks viewers to consider who books are made for, who is imagined as a reader, and what can be lost when tactile heritage is digitised only as flat images.
#
# The project uses human–AI collaboration as part of its creative and interpretive process. Generative AI is used to draft alternative labels, access-description text, and explanatory wording. Python is used to create visual aids that make surface detail easier to notice in a digital environment. However, the AI is not treated as an authority. The human role remains responsible for selecting the object, choosing fragments, checking factual claims, editing language, identifying ethical risks, and deciding how the object should be presented to the public.

# %% [markdown]
# ## Context
#
# The selected object is a raised-type New Testament made for blind readers. It belongs to the University of Glasgow Special Collections and is identified as **Sp Coll RF 256 / RF 257**. As a religious book, it belongs to a long tradition of biblical printing and Christian reading practices. As a tactile book, however, it also belongs to the history of accessibility, disability, education, and reading technologies.
#
# The Bible has had a major influence on Western language, culture, literature, art, and religious practice. For many communities, biblical texts have shaped moral teaching, collective memory, and personal belief. Yet access to biblical knowledge has never been equal. Historically, many people encountered scripture not through private reading, but through sermons, oral teaching, stained glass, paintings, public worship, and communal interpretation. For blind and visually impaired readers, access to printed scripture raised additional questions about format, independence, and material design.
#
# The raised-type New Testament is therefore not only important because of what it says as a biblical text. It is important because of how it was made to be read. Its high-relief letters show that the page was designed for the hand as well as the eye. This changes the way the object can be interpreted. It is not only a religious artefact or a rare book. It is also evidence of an attempt to make reading accessible through material form.
#
# This project approaches the object as a cultural heritage item connected to disability history. It does not present disability as an inspirational theme or as a problem to be solved. Instead, it focuses on design, access, and agency. The object helps open a wider conversation about how cultural institutions describe, digitise, and present materials that were made for different bodies and different reading practices.
#
# In digital heritage, tactile objects can be difficult to represent. A photograph can show the page, but it cannot fully communicate height, pressure, resistance, or the movement of fingers across raised letters. This project therefore asks how a digital mini-exhibit can make tactile features more noticeable without pretending to replace the physical object. The answer developed here is a human–AI workflow that combines object photography, computational visual aids, AI-assisted public writing, and human ethical editing.

# %% [markdown]
# ## Objectives
#
# The overall objective of this project is to engage a general audience with the raised-type New Testament as both a religious object and a historical accessibility technology. The project moves beyond presenting the object simply as an old book. It situates the object within broader questions about reading, disability, digitisation, and public access to cultural heritage.
#
# The project has four main objectives:
#
# 1. **To introduce the object clearly to a non-specialist audience.**
#    The mini-exhibit explains what the raised-type New Testament is, where it is held, and why it matters. It avoids assuming specialist knowledge of rare books, biblical history, disability studies, or artificial intelligence.
#
# 2. **To make the tactile qualities of the object more visible in a digital environment.**
#    Since online visitors cannot touch the object, the project uses close-up photographs and Python-generated relief-enhanced visual aids to draw attention to surface, spacing, and raised letterforms.
#
# 3. **To use generative AI as a support for accessible public interpretation.**
#    Generative AI is used to draft alternative versions of labels and access-description text. These drafts are then edited by the human author for accuracy, clarity, tone, and ethical suitability.
#
# 4. **To critically reflect on the limits of AI and digitisation.**
#    The project makes clear that AI-generated language and processed images are interpretive aids. They do not replace archival evidence, expert cataloguing, or the physical experience of handling a tactile book.
#
# The intended outcome is a small digital exhibit that helps viewers understand accessibility as part of cultural heritage. The project is not assessed on whether the final exhibit is artistically perfect. Its value lies in the clarity of the methodology, the appropriateness of the human–AI collaboration, the accessibility of the presentation, and the integrity of the interpretation.

# %% [markdown]
# ## The audience and public value
#
# The intended audience is a general public audience, including visitors who may not have prior knowledge of rare books, disability history, tactile reading, digitisation, or artificial intelligence. The project is also written for an arts and humanities audience interested in how AI can support interpretation without replacing human expertise.
#
# This audience framing matters because accessibility is not only a topic within the project. It is also a design principle for the portfolio itself. The mini-exhibit therefore avoids presenting the raised-type New Testament only as an unusual curiosity. Instead, it presents the object as a historical example of how reading technologies can include some bodies and exclude others.
#
# The project helps its audience by turning a specialist object into a set of accessible questions:
#
# | Audience need | Mini-exhibit response |
# |---|---|
# | “I do not know what raised type is.” | The introduction and first panel explain raised type in plain language. |
# | “I cannot see the texture clearly in a flat photo.” | Relief-enhanced visual aids help sighted online viewers notice surface variation. |
# | “I do not know why this object matters.” | Labels connect the object to access, design, reading, and cultural heritage. |
# | “I need image descriptions.” | Each panel includes access-description writing rather than relying on images alone. |
# | “I want to know what AI contributed.” | The notebook shows AI draft problems, human revisions, and reasons for editing. |
# | “I want to trust the interpretation.” | The notebook separates evidence-based description from interpretation and states limits clearly. |
#
# ### Audience journey through the exhibit
#
# The audience journey is designed as a movement from recognition to questioning. The visitor first recognises the object as a book. Then the exhibit slows that recognition down by asking what kind of book it is, what kind of reading it supports, and what kind of reader it imagines. Finally, the visitor is invited to connect the historical object to present-day questions about access in museums, libraries, archives, and digital platforms.
#
# This sequence matters because a general audience may not arrive with specialist vocabulary. Terms such as “tactile print,” “raised type,” “digitisation,” or “human–AI workflow” can become barriers if they are introduced too quickly. The exhibit therefore begins with a simple public idea: this is a page designed to be read by touch. From there, it introduces more complex issues: the difference between seeing and touching, the loss of tactile information in photographs, and the responsibility of human editors when AI is used to write access text.
#
# The intended visitor experience is not passive. Each panel includes a visitor question because the project is not only trying to deliver information. It is trying to change the way the viewer thinks about access. The questions ask the visitor to notice design decisions rather than pity blind readers or treat the object as a novelty. This is important because disability-related heritage can easily be misframed as either tragic or inspirational. The project instead treats access as a practical, cultural, and historical question.
#
# The mini-exhibit also tries to avoid a common weakness in digital displays of rare books: showing attractive images without explaining how to read them. A photograph of a raised-type page may look interesting, but without interpretation the viewer may not understand why the surface matters. The combination of close-up images, relief-enhanced visual aids, and access descriptions helps the viewer understand the object at several levels. The viewer can see the page, notice the raised surface, read an explanation, and reflect on the limits of the digital image.
#
# This means that the exhibit is not only about the New Testament. It is about the design of access itself. The object becomes a way to talk about a wider cultural issue: cultural heritage is not automatically accessible because it has been digitised. Access depends on description, interface design, permissions, file quality, language, and the assumptions made about audiences.

# %% [markdown]
# ## Exhibit overview: from object to public interpretation
#
# The mini-exhibit is organised through four interpretive layers. Each layer answers a different visitor question and shows how human judgement, AI-assisted writing, and computational image processing work together.
#
# | Exhibit layer | Visitor question it answers | Human–AI role |
# |---|---|---|
# | Original photograph | What does the object look like? | Human selects images and decides which details are meaningful. |
# | Relief-enhanced visual aid | Where can I notice surface and raised forms? | Python transforms image data; human explains that this is an interpretive visual aid, not a scientific scan. |
# | Plain-language label | Why does this detail matter? | Generative AI drafts possible wording; human edits for accuracy, tone, and public clarity. |
# | Access description | How can the image be described without relying only on sight? | AI suggests wording; human revises to avoid vague, overdramatic, or sentimental language. |
#
# This structure keeps the project focused on public access. Rather than adding a separate experimental layer, the exhibit concentrates on clearer labels, clearer image descriptions, and visual aids that point back to the tactile page.

# %% [markdown]
# ## Knowledge and Themes
#
# * **Accessibility as Cultural Heritage**: The main theme of this project is accessibility. The raised-type New Testament shows that access is not only a present-day issue. It has a history within books, printing, religion, and education. The object encourages viewers to think about accessibility as something built into materials, not simply added afterwards.
#
# * **Reading as a Multisensory Practice**: The project challenges the assumption that reading is mainly visual. Raised type shows that text can be approached through touch. This expands the idea of reading from a purely visual activity to a multisensory practice involving bodies, surfaces, movement, and material design.
#
# * **Disability History and Representation**: The object opens a conversation about blind readers and the historical barriers they faced in accessing printed texts. The project avoids presenting disability through pity or inspiration. Instead, it focuses on access, design, and the social conditions that shape who can read independently.
#
# * **Religion and Material Practice**: Although the object is a New Testament, the project does not treat it only as a religious text. It considers how religious practice is connected to material objects. A Bible is not only a container of words; it is also a designed object used in reading, teaching, devotion, and community life.
#
# * **Digitisation and Loss**: Digitisation increases access, but it can also flatten material experience. A tactile page becomes a flat image on a screen. This project uses visual enhancement to help viewers notice raised features, while also acknowledging that no digital image can fully reproduce touch.
#
# * **Human–AI Collaboration**: The project uses AI to support public interpretation, but it does not treat AI as independent or neutral. AI-generated outputs require human checking, editing, and ethical judgement. This reflects the wider theme of the project: access depends on decisions made by people, tools, and institutions.

# %% [markdown]
# ## Human–AI Collaboration
#
# This project uses AI as a collaborator in the public interpretation process. The collaboration is not based on allowing AI to create an exhibit independently. Instead, AI is used as a tool for generating possible wordings, alternative descriptions, and explanatory drafts. The human author then selects, edits, rejects, or rewrites those outputs.
#
# The human role begins with the selection of the object and the decision to frame it around accessibility. This is an interpretive decision. The AI did not decide that the object should be understood as a historical accessibility technology; that direction came from human research, observation, and ethical judgement.
#
# The AI role appears mainly in the drafting stage. For example, generative AI can produce several versions of a plain-language exhibit label. Some versions may be too vague, too dramatic, or too dependent on sentimental language about blindness. The human author then revises the text to make it more accurate, respectful, and useful for a general audience.
#
# The Python code plays a different role. It is not generative AI in the same way as a text model, but it is part of the computational method of the project. It transforms image data into cropped views and relief-enhanced visual aids. These outputs help viewers notice surface detail in a way that ordinary photographs may not make obvious.
#
# The collaboration can therefore be understood as a workflow:
#
# | Stage | Human contribution | AI/computational contribution | Public value |
# |---|---|---|---|
# | Object framing | Selects the object and defines accessibility as the central theme | None | Gives the exhibit a clear social and cultural purpose |
# | Image selection | Chooses fragments that show raised type and material surface | Python helps crop and enhance images | Helps online visitors notice tactile features |
# | Draft writing | Provides prompts, factual limits, and intended audience | Generative AI suggests label and description wording | Produces multiple possible routes into the object |
# | Human editing | Checks accuracy, tone, disability language, and clarity | AI drafts are revised or rejected | Prevents misleading or insensitive interpretation |
# | Final exhibit | Organises images, labels, access text, and reflection | Code displays outputs in the notebook | Creates a coherent public-facing mini-exhibit |
#
# This means the creative value of the project does not come from AI alone. It comes from the interaction between human intention, machine-generated variation, computational image processing, and critical human revision.

# %% [markdown]
# ## How Generative AI Works in This Project
#
# Generative AI refers to artificial intelligence systems that produce new content based on patterns learned from training data. In this project, generative AI is used mainly for text. It helps draft alternative exhibit labels, access descriptions, and explanatory wording.
#
# The text-based AI model used in this project can be understood through the basic machine-learning workflow:
#
# | Machine-learning stage | How it appears in this project |
# |---|---|
# | Training data | The model has previously been trained on large collections of text from many sources. The exact training data is not fully visible to the user. |
# | Algorithm/model | The model uses a transformer-based architecture that predicts likely sequences of words based on input prompts and learned patterns. |
# | New input | The human author provides prompts describing the object, audience, tone, and ethical constraints. |
# | Output | The model generates draft labels, descriptions, or explanations. |
# | Human verification | The human author checks the output for accuracy, clarity, tone, and ethical suitability. |
#
# Transformer models are especially useful for text generation because they use attention mechanisms to consider relationships between words and phrases. This allows them to generate fluent text. However, fluency does not guarantee truth. A model may produce confident but unsupported claims, especially when asked about a specific archival object. For this reason, the AI output in this project is treated as a draft, not as evidence.
#
# The project also uses Python image processing. This is not generative AI in the same sense as a text model. It does not invent a new image or reconstruct missing features. Instead, it applies computational transformations to existing photographs. For example, a photograph can be converted into grayscale, sharpened, or edge-enhanced to make surface patterns easier to notice. This supports the public-engagement aim, but the resulting image must be labelled as a visual aid rather than as a scientific measurement of texture.
#
# The project therefore distinguishes between:
#
# - **archival evidence**: the original object and photographs;
# - **computational visual aids**: processed images that help viewers notice features;
# - **AI-assisted interpretation**: draft text generated by AI and edited by the human author;
# - **human judgement**: the final decision-making process that checks meaning, tone, ethics, and accuracy.

# %% [markdown]
# ## Methodology
#
# ### Research Question
#
# The project is guided by the following research question:
#
# > **How can human–AI collaboration help transform a raised-type New Testament into an accessible public-facing mini-exhibit that encourages general audiences to think about reading, disability, and cultural heritage?**
#
# This question focuses on public engagement rather than technical novelty. The purpose is not to build a new AI model from scratch. Instead, the project uses existing tools in a documented and critical way.
#
# ### Methodological Approach
#
# The methodology combines four forms of work:
#
# 1. **Digitisation and object observation**
#    Photographs of the raised-type New Testament are used as the starting point. These photographs make the object available within the notebook, but they are also treated critically because they cannot fully reproduce tactile experience.
#
# 2. **Computational image processing**
#    Python is used to generate crops, contact sheets, and relief-enhanced visual aids. This helps viewers notice the raised forms and surface patterning of the pages.
#
# 3. **Generative-AI-assisted writing**
#    Generative AI is used to draft public labels, access-description writing, and alternative explanatory phrasing. The drafts are then edited by the human author.
#
# 4. **Human curation and ethical revision**
#    The human author selects the final images, revises AI outputs, avoids unsupported claims, checks language about disability, and frames the outputs as interpretation rather than archival fact.
#
# The methodology is designed to support the project’s objective: helping a general audience understand accessibility as part of cultural heritage. Each technical step therefore has an interpretive purpose. Cropping is not included only to demonstrate Python skill; it helps focus attention on raised type. AI writing is not included only to demonstrate generative text; it helps test how the object might be explained in clearer public language. Reflection is not included as an afterthought; it is necessary because accessibility, religion, disability, and AI all involve ethical responsibilities.

# %% [markdown]
# ## Technologies Used
#
# 1. **Digitisation and Image Selection**
#
#    The project begins with digital photographs of the raised-type New Testament. These images make it possible to present the object in a Jupyter Notebook. The photographs are treated as evidence of the object’s appearance, but they are not treated as complete replacements for the physical object.
#
#    The human author selected a small number of fragments that show visible raised type, page texture, and layout. This selection process is important because a mini-exhibit cannot show everything. The chosen images act as entry points into the object.
#
# 2. **Python Image Processing**
#
#    Python is used to organise and process the images. The main libraries are:
#    - **Pillow**, for opening, resizing, cropping, and enhancing images;
#    - **NumPy**, for representing images as arrays of numerical values;
#    - **Pandas**, for creating embedded tables in the notebook.
#
#    The image processing creates relief-enhanced visual aids. These outputs help sighted online viewers notice surface detail more clearly. However, the project makes clear that these images are interpretive aids. They do not reproduce touch and should not be mistaken for the physical experience of reading raised type.
#
# 3. **Generative Text AI**
#
#    Generative text AI is used to draft alternative labels and access-description style writing. The prompts ask for clear, non-specialist language and caution against invented historical claims. The outputs are then edited by the human author.
#
#    This use of AI is appropriate because the project is concerned with public communication. A generative text model can quickly offer several possible ways to explain an object. However, the model does not know the object in the same way that a human researcher or archivist does. It may generalise, overstate, or use unsuitable language. For this reason, AI output is always checked and revised.

# %% [markdown]
# ## Project Execution
#
# The project execution brings together the public-facing aim, the human–AI methodology, and the technical work in the notebook. The aim is not to use code or AI for their own sake. Each step is included because it helps a general audience understand the raised-type New Testament as a historical accessibility technology.
#
# The execution follows a simple structure:
#
# 1. creating a digital working set from the object photographs;
# 2. building a contact sheet as the visual entry point;
# 3. choosing fragments for interpretation;
# 4. generating relief-enhanced visual aids with Python;
# 5. comparing photographic and processed views;
# 6. showing how AI-style draft wording was revised by the human author;
# 7. building the final mini-exhibit panels.
#
# This section is therefore both technical and interpretive. The code creates the visual materials used in the exhibit, while the written reflection explains why those materials matter for public engagement.

# %% [markdown]
# ### Step 1: Selecting and framing the object
#
# The selected object is a tactile New Testament printed in high relief for blind readers, held by the University of Glasgow Special Collections as **Sp Coll RF 256 / RF 257**. The object was chosen because it connects rare book history with accessibility, disability history, religious practice, and the material design of reading.
#
# The project does not focus mainly on the biblical content of the New Testament. Instead, it focuses on the object’s form: a printed book designed to be read through touch. This makes it especially useful for a public mini-exhibit because it encourages visitors to ask what reading is and who books are made for.
#
# The central interpretive decision was to frame the object as a historical accessibility technology. This framing shaped the rest of the project. It influenced which images were selected, what the Python code was designed to show, how the AI-generated text was edited, and how the final exhibit panels were written.

# %% [markdown]
# ### Step 2: Creating a digital working set
#
# The project begins with a small set of photographs of the raised-type New Testament. These photographs are stored in the repository so that the notebook can be run again and the visual outputs can be regenerated.
#
# This step is important because the physical object must first become digital data before it can be used in a Jupyter Notebook. However, the notebook treats digitisation critically. A photograph can make the object visible to online audiences, but it cannot reproduce the pressure, scale, or movement involved in reading by touch.
#
# The following code locates the images in the repository and creates a basic inventory.

# %%
# Code Cell 1: Imports and package check
# Pillow is installed as "Pillow" but imported in Python as "PIL".

import sys
from pathlib import Path

try:
    from PIL import Image, ImageEnhance, ImageFilter, ImageDraw, ImageOps
except ModuleNotFoundError:
    # !{sys.executable} -m pip install Pillow
    from PIL import Image, ImageEnhance, ImageFilter, ImageDraw, ImageOps

try:
    import numpy as np
except ModuleNotFoundError:
    # !{sys.executable} -m pip install numpy
    import numpy as np

try:
    import pandas as pd
except ModuleNotFoundError:
    # !{sys.executable} -m pip install pandas
    import pandas as pd

from IPython.display import display, Image as IPImage, Markdown

print("Packages loaded successfully.")

# %%
# Code Cell 2: Folder setup and image loading

PROJECT_ROOT = Path.cwd()

ORIGINAL_DIR = PROJECT_ROOT / "images"
PROCESSED_DIR = PROJECT_ROOT / "processed_images"
OUTPUT_DIR = PROJECT_ROOT / "outputs"
CONTACT_DIR = OUTPUT_DIR / "contact_sheet"

# Create folders for generated outputs.
for folder in [PROCESSED_DIR, OUTPUT_DIR, CONTACT_DIR]:
    folder.mkdir(parents=True, exist_ok=True)

# Locate image files in the images folder.
image_extensions = [".jpg", ".jpeg", ".png", ".webp"]

if not ORIGINAL_DIR.exists():
    raise FileNotFoundError(
        "The notebook cannot find a folder called 'images'. "
        "Create a folder named 'images' in the same location as this notebook, "
        "then place your object photographs inside it."
    )

image_paths = sorted(
    [p for p in ORIGINAL_DIR.iterdir() if p.suffix.lower() in image_extensions]
)

if not image_paths:
    raise FileNotFoundError(
        "No image files were found in the 'images' folder. "
        "Make sure your photographs are .jpg, .jpeg, .png, or .webp files."
    )

print(f"Found {len(image_paths)} image file(s):")
for path in image_paths:
    print("-", path.name)

# %% [markdown]
# The inventory is not only a technical check. It also records the digital working set used by the project. This matters for research integrity because the mini-exhibit should make clear which visual materials it is based on.

# %%
# Code Cell 3: Image inventory

inventory_rows = []

for path in image_paths:
    with Image.open(path) as im:
        inventory_rows.append({
            "file name": path.name,
            "width": im.width,
            "height": im.height,
            "format": im.format,
            "mode": im.mode
        })

image_inventory = pd.DataFrame(inventory_rows)
display(image_inventory)

# %% [markdown]
# The image inventory records the digital working set used by the project. This helps make the portfolio more transparent because the viewer can see which image files are being used to build the mini-exhibit.

# %% [markdown]
# ### Step 3: Creating a contact sheet
#
# The contact sheet acts as the visual entry point to the mini-exhibit. It gives the viewer an overview of the selected photographs before the notebook focuses on individual fragments.
#
# For the project workflow, the contact sheet also makes the process more reproducible. It is generated from the image files in the repository rather than inserted manually.

# %%
# Code Cell 4: Build a contact sheet as the visual entry point to the exhibit.
# The contact sheet is generated from the repository images so that the notebook remains reproducible.

thumbs = []

for path in image_paths:
    im = Image.open(path).convert("RGB")
    im.thumbnail((220, 220))
    thumbs.append((path.name, im.copy()))

cols = 2
cell_w, cell_h = 520, 285
rows = int(np.ceil(len(thumbs) / cols))

sheet = Image.new("RGB", (cols * cell_w, rows * cell_h), "white")
draw = ImageDraw.Draw(sheet)

for idx, (name, im) in enumerate(thumbs):
    x = (idx % cols) * cell_w + 20
    y = (idx // cols) * cell_h + 20
    sheet.paste(im, (x, y))
    draw.text((x + 240, y + 70), name, fill="black")

contact_path = CONTACT_DIR / "selected_images_contact_sheet.jpg"
sheet.save(contact_path, quality=90)

display(IPImage(filename=str(contact_path)))

# %% [markdown]
# The contact sheet acts as the visual entry point to the mini-exhibit. It gives the viewer an overview of the selected photographs before the notebook focuses on individual fragments.
#
# For the project workflow, the contact sheet also makes the process reproducible. It is generated from the image files in the `images` folder rather than manually inserted as a separate design element.

# %% [markdown]
# ### Step 4: Choosing fragments for interpretation
#
# A mini-exhibit cannot show every part of the object. It needs a small number of focused fragments that help the audience understand the main idea.
#
# The following table records the interpretive role of each selected fragment. The table is embedded inside the notebook rather than stored as a separate spreadsheet because it is part of the exhibit itself. It explains how each fragment contributes to the public argument about access, touch, and reading.

# %%
# Code Cell 5: Choose fragments for interpretation.
# The function below safely chooses images even if the folder contains fewer than three files.

def choose_image(index):
    return image_paths[min(index, len(image_paths) - 1)]

fragment_choices = pd.DataFrame([
    {
        "fragment": "Fragment 1",
        "source image": choose_image(4).name,
        "public focus": "The page as a tactile reading surface",
        "why it was chosen": "Introduces the object as a book designed for touch rather than only sight.",
        "visitor question": "What kind of reading does this page invite?"
    },
    {
        "fragment": "Fragment 2",
        "source image": choose_image(6).name,
        "public focus": "Raised letterforms and surface detail",
        "why it was chosen": "Helps viewers notice that the printed surface is functional, not decorative.",
        "visitor question": "Where can I see evidence of raised type?"
    },
    {
        "fragment": "Fragment 3",
        "source image": choose_image(2).name,
        "public focus": "The limits of flat digitisation",
        "why it was chosen": "Shows why photographs need interpretation when the object’s meaning depends on touch.",
        "visitor question": "What might be lost when tactile heritage becomes a flat image?"
    }
])

display(fragment_choices)

# %% [markdown]
# The fragment choices show that selection is part of interpretation. The chosen images are not random illustrations. They guide the audience through the project’s central argument: the raised-type New Testament matters because it reveals access as a design choice.
#
# The table is embedded directly in the notebook because it is part of the mini-exhibit. It explains how each selected image helps the visitor understand access, touch, and reading.

# %% [markdown]
# ### Step 5: Creating relief-enhanced visual aids
#
# The next step uses Python to create visual aids from the photographs. These outputs are called **relief-enhanced visual aids** rather than scans or measurements. This wording matters because the code does not scientifically measure the height of the raised type. It only transforms the image to make contrast and surface variation easier to notice.
#
# This is useful for sighted online viewers who cannot handle the object directly. The processed image helps them notice features that may be less obvious in an ordinary photograph.
#
# At the same time, the project is careful about the limits of this method. A relief-enhanced image cannot reproduce touch. It cannot show pressure, resistance, scale, or the movement of fingertips across the page. It is an interpretive aid, not a replacement for the object.

# %%
# Code Cell 6: Functions for cropping and creating relief-enhanced visual aids.

def crop_by_percentage(image, crop_pct):
    """
    Crop an image using percentage coordinates.
    crop_pct should be (left, top, right, bottom), with each value between 0 and 1.
    """
    width, height = image.size
    left = int(width * crop_pct[0])
    top = int(height * crop_pct[1])
    right = int(width * crop_pct[2])
    bottom = int(height * crop_pct[3])
    return image.crop((left, top, right, bottom))


def create_relief_visual_aid(image):
    """
    Create an interpretive visual aid that makes surface variation easier to notice.
    
    This does not measure physical relief. It enhances contrast and edge information
    in the photograph so that sighted online viewers can better notice surface detail.
    """
    # Convert to grayscale so that tonal differences are easier to process.
    gray = ImageOps.grayscale(image)

    # Increase contrast to make surface variation more noticeable.
    contrast = ImageEnhance.Contrast(gray).enhance(1.8)

    # Sharpen image details.
    sharp = ImageEnhance.Sharpness(contrast).enhance(2.0)

    # Find edges and blend them with the enhanced grayscale image.
    edges = sharp.filter(ImageFilter.FIND_EDGES)
    edges = ImageEnhance.Contrast(edges).enhance(1.7)

    blended = Image.blend(sharp.convert("RGB"), edges.convert("RGB"), 0.35)

    return blended


print("Cropping and relief-enhancement functions are ready.")

# %% [markdown]
# The relief-enhanced image is not a scientific scan of the page. It does not measure the height of the raised letters. It is an interpretive visual aid that makes surface variation easier to notice in a flat digital image.
#
# This distinction matters because the project should not overclaim what Python image processing can do. The processed images support public interpretation, but they do not replace the physical object or the tactile experience of reading by touch.

# %% [markdown]
# ### Step 6: Comparing the visual outputs
#
# The next code cell displays each selected crop beside its relief-enhanced version. This comparison is the technical centre of the project. It shows how a photograph can be transformed to support public interpretation.
#
# The comparison also shows the limits of the method. The processed image may make some details easier to notice, but it should not be confused with the physical surface of the page.

# %%
# Code Cell 7: Generate cropped images and relief-enhanced visual aids.

fragment_plan = [
    {
        "fragment": "Fragment 1",
        "source": choose_image(4),
        "crop_pct": (0.05, 0.05, 0.95, 0.75)
    },
    {
        "fragment": "Fragment 2",
        "source": choose_image(6),
        "crop_pct": (0.10, 0.10, 0.90, 0.80)
    },
    {
        "fragment": "Fragment 3",
        "source": choose_image(2),
        "crop_pct": (0.05, 0.15, 0.95, 0.90)
    }
]

fragment_records = []

for item in fragment_plan:
    source_path = item["source"]
    original = Image.open(source_path).convert("RGB")

    cropped = crop_by_percentage(original, item["crop_pct"])
    cropped.thumbnail((900, 900))

    relief = create_relief_visual_aid(cropped)

    fragment_id = item["fragment"].lower().replace(" ", "_")

    crop_path = PROCESSED_DIR / f"{fragment_id}_crop.jpg"
    relief_path = PROCESSED_DIR / f"{fragment_id}_relief_visual_aid.jpg"

    cropped.save(crop_path, quality=90)
    relief.save(relief_path, quality=90)

    fragment_records.append({
        "fragment": item["fragment"],
        "source image": source_path.name,
        "crop path": str(crop_path.relative_to(PROJECT_ROOT)),
        "relief visual aid path": str(relief_path.relative_to(PROJECT_ROOT))
    })

processed_fragments = pd.DataFrame(fragment_records)
display(processed_fragments)

# %% [markdown]
# The table above shows the generated image outputs. These images are used directly in the mini-exhibit. The cropped image provides a closer photographic view, while the relief-enhanced visual aid helps the audience notice surface variation.
#
# The purpose is not to make the page look more dramatic. The purpose is to support the visitor’s understanding of raised type as an access technology.

# %% [markdown]
# ### Step 7: A small technical summary
#
# The following code gives a simple technical summary of the processed fragments. It calculates the average brightness and a rough edge-density value for each crop and relief-enhanced visual aid.
#
# This is not a scientific measurement of raised type. It is included to show that the code is doing a visible transformation to the image data. The values help explain the difference between the photographic crop and the enhanced visual aid in a way that is transparent to the reader.

# %%
# Code Cell 8: Create side-by-side comparison images.

def make_comparison_image(crop_path, relief_path, title):
    """
    Create a side-by-side comparison image for the mini-exhibit.
    """
    crop = Image.open(crop_path).convert("RGB")
    relief = Image.open(relief_path).convert("RGB")

    target_height = 420

    def resize_to_height(im, height):
        ratio = height / im.height
        return im.resize((int(im.width * ratio), height))

    crop = resize_to_height(crop, target_height)
    relief = resize_to_height(relief, target_height)

    padding = 30
    title_h = 60
    label_h = 40

    width = crop.width + relief.width + padding * 3
    height = target_height + title_h + label_h + padding

    canvas = Image.new("RGB", (width, height), "white")
    draw = ImageDraw.Draw(canvas)

    draw.text((padding, 20), title, fill="black")
    draw.text((padding, title_h), "Photographic crop", fill="black")
    draw.text((crop.width + padding * 2, title_h), "Relief-enhanced visual aid", fill="black")

    canvas.paste(crop, (padding, title_h + label_h))
    canvas.paste(relief, (crop.width + padding * 2, title_h + label_h))

    return canvas


comparison_paths = []

for _, row in processed_fragments.iterrows():
    crop_path = PROJECT_ROOT / row["crop path"]
    relief_path = PROJECT_ROOT / row["relief visual aid path"]

    comparison = make_comparison_image(
        crop_path,
        relief_path,
        f"{row['fragment']}: photograph and interpretive visual aid"
    )

    comparison_path = PROCESSED_DIR / f"{row['fragment'].lower().replace(' ', '_')}_comparison.jpg"
    comparison.save(comparison_path, quality=90)
    comparison_paths.append(comparison_path)

    display(IPImage(filename=str(comparison_path)))

# %% [markdown]
# The comparison images are the technical centre of the project. They show how a photograph can be transformed to support public interpretation.
#
# The processed view may make surface detail easier to notice, but it should not be confused with the physical surface of the page. This is important because the object’s meaning depends on touch, and touch cannot be fully reproduced in a notebook.

# %%
# Code Cell 9: Create a small technical summary.
# This is not a scientific measurement of raised type.
# It only describes simple visual differences between original crops and processed visual aids.

def image_summary(path):
    """
    Return simple brightness and edge-density values for an image.
    These values are used only as a basic technical description.
    """
    im = Image.open(path).convert("L").resize((400, 400))
    arr = np.asarray(im).astype(float)

    brightness = arr.mean()

    horizontal_change = np.abs(np.diff(arr, axis=1)).mean()
    vertical_change = np.abs(np.diff(arr, axis=0)).mean()
    edge_density = horizontal_change + vertical_change

    return brightness, edge_density


summary_rows = []

for _, row in processed_fragments.iterrows():
    crop_path = PROJECT_ROOT / row["crop path"]
    relief_path = PROJECT_ROOT / row["relief visual aid path"]

    crop_brightness, crop_edges = image_summary(crop_path)
    relief_brightness, relief_edges = image_summary(relief_path)

    summary_rows.append({
        "fragment": row["fragment"],
        "crop average brightness": round(crop_brightness, 2),
        "crop edge-density estimate": round(crop_edges, 2),
        "relief aid average brightness": round(relief_brightness, 2),
        "relief aid edge-density estimate": round(relief_edges, 2)
    })

technical_summary = pd.DataFrame(summary_rows)
display(technical_summary)

# %% [markdown]
# The edge-density estimate is included carefully. It does not prove where the raised letters are or how high they are. It simply shows that the processed images contain stronger local contrast than the original crops.
#
# For the audience, this supports the visual task of noticing surface variation. For the project methodology, it shows that the visual aids are generated through a transparent computational process rather than manually edited without explanation.

# %% [markdown]
# ### Step 8: Generative AI drafting and human revision
#
# Generative AI was used to help draft public-facing language. This included possible exhibit labels, access-description writing, and short explanations of the object. The AI was useful because it could quickly suggest alternative phrasings for non-specialist audiences.
#
# However, the AI output was not accepted automatically. It needed human revision. This is especially important because AI-generated text can sound confident while still being vague, inaccurate, or ethically unsuitable. When writing about disability history, language needs careful attention. The project avoids pity-based, inspirational, or sentimental framing and focuses instead on access, design, and readers.
#
# The following table is embedded directly in the notebook to show the kind of human–AI revision involved in the project.

# %%
# Code Cell 10: Human-AI drafting and revision examples.
# These examples show the type of revision used in the project.

ai_revision_examples = pd.DataFrame([
    {
        "task": "Plain-language exhibit label",
        "AI-style draft problem": "The wording described the object as an inspiring example of overcoming blindness.",
        "human revision decision": "Reframed the label around design, access, and tactile reading.",
        "why the revision mattered": "Avoids sentimental disability language and focuses on the object as accessibility technology."
    },
    {
        "task": "Access description",
        "AI-style draft problem": "The description said only that the image showed an old page with text.",
        "human revision decision": "Added details about raised letterforms, spacing, page surface, and the limits of the flat image.",
        "why the revision mattered": "Makes the description more useful for audiences who cannot rely on the image alone."
    },
    {
        "task": "Historical explanation",
        "AI-style draft problem": "The draft made broad claims about blind readers in the nineteenth century without evidence from the object.",
        "human revision decision": "Limited the claim to what the object and catalogue information support.",
        "why the revision mattered": "Prevents AI from turning plausible generalisation into unsupported archival fact."
    },
    {
        "task": "Visitor question",
        "AI-style draft problem": "The question asked visitors to imagine what it is like to be blind.",
        "human revision decision": "Changed the question to ask how reading changes when touch becomes central.",
        "why the revision mattered": "Avoids disability simulation and keeps attention on design and access."
    }
])

display(ai_revision_examples)

# %% [markdown]
# This table shows that the human–AI collaboration is not simply a division of labour where AI produces content and the human inserts it into the notebook. The collaboration is critical. AI provides variation, but the human author decides what is accurate, respectful, and useful for the exhibit.
#
# This is especially important for disability-related heritage. The final labels avoid pity-based or inspirational language and focus instead on design, access, and reading.

# %% [markdown]
# ## Mini-Exhibit Panels
#
# The following panels form the public-facing mini-exhibit. Each panel combines a visual fragment, a plain-language label, an access-description style text, and a visitor question.
#
# The panels are written for a general audience. They avoid specialist language where possible and explain the object through access, material design, and reading practice.

# %%
# Code Cell 11: Mini-exhibit panel text.

mini_exhibit_panels = pd.DataFrame([
    {
        "panel": "Panel 1",
        "title": "A page designed for fingertips",
        "plain-language label": (
            "This page was not designed only to be seen. Its raised letters were made so that "
            "a blind reader could follow the text by touch. The page reminds us that reading "
            "depends on the relationship between bodies, surfaces, and design."
        ),
        "access description": (
            "A close view of a page from a raised-type New Testament. The surface contains rows "
            "of raised letterforms. In a flat photograph, the tactile quality is difficult to fully "
            "experience, but the visible surface and spacing suggest a page made for touch."
        ),
        "visitor question": "What changes when a book imagines the reader’s fingertips as the main way into the text?"
    },
    {
        "panel": "Panel 2",
        "title": "Raised type as access technology",
        "plain-language label": (
            "The raised forms are not decoration. They are part of the book’s access system. "
            "They show how print can be redesigned when the reader is not assumed to be sighted."
        ),
        "access description": (
            "This fragment focuses on the surface of the page. The relief-enhanced visual aid "
            "makes changes in tone and edge detail easier to notice, helping sighted online viewers "
            "understand that the page has a tactile structure."
        ),
        "visitor question": "Who is included or excluded when reading is designed around one sense?"
    },
    {
        "panel": "Panel 3",
        "title": "What digitisation can lose",
        "plain-language label": (
            "Digitisation can make rare objects easier to share, but it can also flatten them. "
            "For tactile objects, a photograph may show the page while hiding part of how it works."
        ),
        "access description": (
            "The panel compares the photographed page with a processed visual aid. The processed "
            "image helps highlight surface variation, but it cannot reproduce pressure, scale, "
            "or the movement of reading by touch."
        ),
        "visitor question": "Is an object fully accessible online if the digital version loses the thing that made it usable?"
    }
])

display(mini_exhibit_panels[["panel", "title", "visitor question"]])

# %% [markdown]
# The mini-exhibit panels combine the main elements of the project. The photographs provide evidence of the object. The relief-enhanced images support visual noticing. The labels explain why the object matters. The access descriptions reduce dependence on sight alone. The visitor questions invite reflection rather than passive viewing.

# %% [markdown]
# ### Displaying the mini-exhibit
#
# The code below displays each mini-exhibit panel with its comparison image and public-facing text.

# %%
# Code Cell 12: Display the mini-exhibit panels.

for idx, row in mini_exhibit_panels.iterrows():
    display(Markdown(f"### {row['panel']}: {row['title']}"))

    if idx < len(comparison_paths):
        display(IPImage(filename=str(comparison_paths[idx])))

    display(Markdown(f"**Plain-language label**  \n{row['plain-language label']}"))
    display(Markdown(f"**Access description**  \n{row['access description']}"))
    display(Markdown(f"**Visitor question**  \n> {row['visitor question']}"))

# %% [markdown]
# ## Discussion: Access, AI, and Public Interpretation
#
# The project shows that human–AI collaboration can support cultural heritage interpretation when it is used with clear limits. Generative AI is helpful for drafting alternative public labels and access descriptions because it can quickly generate different phrasings. This is useful when the aim is to communicate with non-specialist audiences. However, the AI cannot decide what is historically accurate, ethically appropriate, or respectful.
#
# This limitation is especially important in a project about disability and access. AI-generated language can easily become too general or too sentimental. It may describe an accessibility object through ideas of inspiration or overcoming, rather than through design, rights, and material practice. Human editing is therefore not a minor final correction. It is a central part of the methodology.
#
# The relief-enhanced visual aids also require careful interpretation. They make the raised surface easier to notice, but they do not reproduce touch. A viewer may be able to see more contrast in the processed image, but that does not mean they understand the bodily experience of reading with fingertips. This is why the notebook repeatedly labels the processed images as interpretive visual aids rather than scientific scans.
#
# The project therefore treats access in two ways. First, access is the subject of the exhibit: the object itself is a historical example of designing reading for blind readers. Second, access is the method of the exhibit: the notebook uses plain language, image descriptions, tables, and visual comparisons to make the interpretation easier to follow.
#
# This matters because cultural heritage is not automatically accessible just because it has been digitised. A digital image may increase visibility, but it can still exclude audiences if it lacks description, context, permissions clarity, or accessible design. For tactile objects, digitisation can create a particular problem: it shares the object visually while losing the tactile quality that made the object significant.
#
# The project also shows that AI should not be understood as replacing human expertise. In this portfolio, AI supports drafting and variation, while Python supports visual transformation. The human author remains responsible for the curatorial argument, ethical judgement, factual checking, accessibility decisions, and final presentation. This is the most important part of the collaboration.

# %% [markdown]
# ## Ethical, Legal, and Archival Considerations
#
# The project raises several ethical and legal considerations.
#
# First, the object images are photographs of a University of Glasgow Special Collections object. They are used here for coursework purposes. The object should be credited as:
#
# **Tactile New Testament printed in high relief for blind readers, c. 1850, University of Glasgow Special Collections, Sp Coll RF 256 / RF 257.**
#
# The images should not be treated as openly licensed unless University of Glasgow Special Collections confirms the relevant reuse terms. Before sharing the images beyond coursework assessment, permissions and licensing conditions should be checked.
#
# Second, the project must be clear about the difference between evidence and interpretation. The photographs show visible features of the object. The relief-enhanced images are computational interpretations of those photographs. The labels and access descriptions are public-facing interpretations written by the human author with AI assistance. These categories should not be confused.
#
# Third, the project works with disability-related heritage. This requires careful language. The notebook avoids treating blind readers as objects of pity or as inspirational symbols. It focuses instead on access, design, material reading practices, and the social conditions that shape who can read independently.
#
# Fourth, the project uses generative AI. AI-generated text may contain unsupported claims or unsuitable tone. For that reason, the AI is used only as a drafting tool. The human author verifies and revises the outputs before they appear in the final exhibit.
#
# Finally, the project acknowledges the limits of digital access. A notebook can help audiences understand the object, but it cannot replace archival handling, expert cataloguing, or tactile experience. This limitation is not hidden. It is part of the project’s argument.

# %% [markdown]
# ## Conclusion
#
# **Access Through Touch** presents the raised-type New Testament as a historical accessibility technology and a cultural heritage object. The project argues that accessibility is not separate from heritage. It is part of how objects are made, used, preserved, described, and shared.
#
# The mini-exhibit uses human curation, generative-AI-assisted writing, and Python image processing to help a general audience notice the object’s tactile significance. The photographs provide visual evidence. The relief-enhanced images help viewers see surface detail more clearly. The plain-language labels and access descriptions translate specialist concerns into public-facing interpretation. The embedded tables show that audience needs, fragment choices, and AI revision decisions are part of the exhibit, not hidden behind it.
#
# The project also shows that AI must be handled carefully. It can assist with wording and variation, but it cannot decide what is historically accurate, ethically appropriate, or respectful. Those decisions require human responsibility. In this project, AI supports the creative process, but the human author remains the curator, editor, and ethical decision-maker.
#
# The final result is not a replacement for the physical object. Instead, it is a digital access layer that helps viewers think differently about the object. It encourages audiences to see raised type not as a curiosity, but as evidence of how access, reading, religion, and design are connected.

# %% [markdown]
# ## Final Reflection
#
# This project began with a simple observation: the selected New Testament was made to be read by touch. That observation led to a wider question about cultural heritage access. If the object’s meaning depends partly on tactile design, then a digital photograph cannot fully communicate it on its own. The project therefore needed to do more than display images. It needed to explain how the page works, why that matters, and what is lost when tactile heritage becomes flat digital content.
#
# The human–AI collaboration helped develop this interpretation. Generative AI was useful for producing alternative wording and testing how the object might be explained to a general audience. It helped move from specialist description toward clearer public language. However, the most important decisions remained human decisions. The human author decided the project’s argument, selected the fragments, checked the claims, edited the tone, and rejected wording that risked simplifying or sentimentalising disability.
#
# The Python work also shaped the project. Creating relief-enhanced visual aids made the notebook more than a written explanation. It allowed the audience to compare an ordinary photograph with a processed version that draws attention to surface variation. This technical step supported the public aim because it helped viewers notice the object as a tactile page. At the same time, the code also revealed a limitation: visual enhancement can point toward touch, but it cannot reproduce it.
#
# The strongest lesson from the project is that access is not only a topic to discuss. It is a responsibility in how the project is designed. The notebook therefore uses plain language, access descriptions, embedded tables, and clear labels. These choices are not decorative. They are part of the argument that cultural heritage interpretation should consider who is being addressed and who might otherwise be excluded.
#
# The project also changed how I understand the role of AI in arts and humanities work. AI is most useful here not as a replacement for research or interpretation, but as a tool that creates possibilities for the human author to evaluate. Its value comes from the dialogue between generated drafts and human judgement. In this project, that dialogue made the final exhibit clearer, more accessible, and more critically aware.

# %% [markdown]
# ## Sources and Further Reading
#
# The project was informed by the course materials for **AI for the Arts and Humanities (B)**, especially the assessment guidance on human–AI collaboration, public engagement, methodology, accessibility, and research integrity.
#
# Relevant sources and materials include:
#
# - University of Glasgow Special Collections object: **Tactile New Testament printed in high relief for blind readers, c. 1850, Sp Coll RF 256 / RF 257**.
# - AI for the Arts and Humanities (B), assessment submission guide for the project portfolio.
# - AI for the Arts and Humanities (B), course workbook and lecture materials on generative AI, machine-learning workflow, and human–AI collaboration.
# - Course materials on generative models, transformer models, training data, input/output, and the role of human supervision.
# - Documentation for Python, Pillow, NumPy, and Pandas.
# - University of Glasgow Archives & Special Collections guidance on object access, attribution, and permissions.
#
# The object images are used for coursework purposes. They should not be reused publicly without confirming the relevant permissions and licensing conditions with University of Glasgow Special Collections.
